# %%
import torch
import math
from torch import nn
import torch.nn.functional as F

def scaled_dot_product(q, k, v, mask=None):
    # Tính toán attention scores sử dụng scaled dot-product attention
    # q: tensor kích thước 30 x 8 x 200 x 64 (batch_size x num_heads x seq_len x head_dim)
    # k: tensor cùng kích thước với q
    # v: tensor cùng kích thước với q
    # mask: tensor kích thước 200 x 200 (seq_len x seq_len) để che các vị trí không hợp lệ
    
    d_k = q.size()[-1]  # Lấy kích thước chiều cuối (head_dim = 64)
    # Tính tích vô hướng giữa q và k, chia cho căn bậc 2 của d_k để tránh giá trị quá lớn
    scaled = torch.matmul(q, k.transpose(-1, -2)) / math.sqrt(d_k) # Kết quả: 30 x 8 x 200 x 200
    print(f"scaled.size() : {scaled.size()}")
    
    if mask is not None:
        print(f"-- ADDING MASK of shape {mask.size()} --") 
        scaled += mask  # Thêm mask vào attention scores (thường dùng để che các token tương lai trong decoder)
    
    # Áp dụng softmax để chuẩn hóa thành phân phối xác suất
    attention = F.softmax(scaled, dim=-1) # 30 x 8 x 200 x 200
    
    # Nhân attention weights với value vectors để ra output
    values = torch.matmul(attention, v) # 30 x 8 x 200 x 64
    
    return values, attention


class PositionwiseFeedForward(nn.Module):
    # Lớp feed-forward áp dụng cho từng vị trí độc lập trong chuỗi
    def __init__(self, d_model, hidden, drop_prob=0.1):
        super(PositionwiseFeedForward, self).__init__()
        # Lớp linear thứ nhất mở rộng chiều từ d_model lên hidden
        self.linear1 = nn.Linear(d_model, hidden)
        # Lớp linear thứ hai thu hẹp về lại d_model
        self.linear2 = nn.Linear(hidden, d_model)
        self.relu = nn.ReLU()  # Hàm kích hoạt
        self.dropout = nn.Dropout(p=drop_prob)  # Dropout để tránh overfitting

    def forward(self, x):
        #  x: input tensor kích thước 30 x 200 x 512 (batch_size x seq_len x d_model)
        x = self.linear1(x) #30 x 200 x 2048
        print(f"x after first linear layer: {x.size()}")
        x = self.relu(x) #30 x 200 x 2048
        print(f"x after relu layer: {x.size()}")
        x = self.dropout(x) #30 x 200 x 2048
        print(f"x after dropout layer: {x.size()}")
        x = self.linear2(x) #30 x 200 x 512
        print(f"x after 2nd linear layer: {x.size()}")
        return x #30 x 200 x 512


class LayerNormalization(nn.Module):
    # Lớp chuẩn hóa theo layer (Layer Normalization)
    def __init__(self, parameters_shape, eps=1e-5):
        super().__init__()
        self.parameters_shape=parameters_shape  # Kích thước đầu vào [d_model]
        self.eps=eps  # Hằng số nhỏ để tránh chia cho 0
        # Tham số scale (gamma) khởi tạo bằng 1
        self.gamma = nn.Parameter(torch.ones(parameters_shape)) # 512
        # Tham số shift (beta) khởi tạo bằng 0
        self.beta =  nn.Parameter(torch.zeros(parameters_shape)) # 512

    def forward(self, inputs):
        # inputs : tensor kích thước 30 x 200 x 512
        dims = [-(i + 1) for i in range(len(self.parameters_shape))] # [-1]
        print(f"dims: {dims}")
        # Tính mean theo chiều cuối (d_model)
        mean = inputs.mean(dim=dims, keepdim=True) #30 x 200 x 1
        print(f"Mean ({mean.size()})")
        # Tính variance
        var = ((inputs - mean) ** 2).mean(dim=dims, keepdim=True) # 30 x 200 x 512
        std = (var + self.eps).sqrt() # 30 x 200 x 512
        print(f"Standard Deviation  ({std.size()})")
        # Chuẩn hóa
        y = (inputs - mean) / std # 30 x 200 x 512
        print(f"y: {y.size()}")
        # Scale và shift
        out = self.gamma * y  + self.beta  # 30 x 200 x 512
        print(f"out: {out.size()}")
        return out

class MultiHeadAttention(nn.Module):
    # Lớp multi-head attention
    def __init__(self, d_model, num_heads):
        super().__init__()
        self.d_model = d_model  # Kích thước embedding (512)
        self.num_heads = num_heads  # Số lượng heads (8)
        self.head_dim = d_model // num_heads  # Kích thước mỗi head (64)
        # Lớp linear để tạo q, k, v từ input
        self.qkv_layer = nn.Linear(d_model , 3 * d_model) # 1536 
        # Lớp linear cuối cùng
        self.linear_layer = nn.Linear(d_model, d_model)
    
    def forward(self, x, mask=None):
        batch_size, sequence_length, d_model = x.size() # 30 x 200 x 512 
        print(f"x.size(): {x.size()}")
        # Tạo q, k, v từ input
        qkv = self.qkv_layer(x) # 30 x 200 x 1536
        print(f"qkv.size(): {qkv.size()}")
        # Reshape để tách thành các head
        qkv = qkv.reshape(batch_size, sequence_length, self.num_heads, 3 * self.head_dim) # 30 x 200 x 8 x 192
        print(f"qkv after reshape .size(): {qkv.size()}")
        # Permute để đưa num_heads lên trước
        qkv = qkv.permute(0, 2, 1, 3) # 30 x 8 x 200 x 192
        print(f"qkv after permutation: {qkv.size()}")
        # Chia thành q, k, v riêng biệt
        q, k, v = qkv.chunk(3, dim=-1) # q: 30 x 8 x 200 x 64, k: 30 x 8 x 200 x 64, v: 30 x 8 x 200 x 64
        print(f"q: {q.size()}, k:{k.size()}, v:{v.size()}")
        # Tính scaled dot-product attention
        values, attention = scaled_dot_product(q, k, v, mask) # values: 30 x 8 x 200 x 64
        print(f"values: {values.size()}, attention:{attention.size()}")
        # Kết hợp các head lại
        values = values.reshape(batch_size, sequence_length, self.num_heads * self.head_dim) # 30 x 200 x 512
        print(f"values after reshaping: {values.size()}")
        # Qua lớp linear cuối cùng
        out = self.linear_layer(values) # 30 x 200 x 512
        print(f"out after passing through linear layer: {out.size()}")
        return out # 30 x 200 x 512


class MultiHeadCrossAttention(nn.Module):
    # Lớp multi-head cross attention (dùng cho encoder-decoder attention)
    def __init__(self, d_model, num_heads):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        # Lớp linear cho key và value (từ encoder output)
        self.kv_layer = nn.Linear(d_model , 2 * d_model) # 1024
        # Lớp linear cho query (từ decoder output)
        self.q_layer = nn.Linear(d_model , d_model)
        # Lớp linear cuối cùng
        self.linear_layer = nn.Linear(d_model, d_model)
    
    def forward(self, x, y, mask=None):
        # x: encoder output (30 x 200 x 512)
        # y: decoder output (30 x 200 x 512)
        batch_size, sequence_length, d_model = x.size() # 30 x 200 x 512
        print(f"x.size(): {x.size()}")
        # Tạo key và value từ encoder output
        kv = self.kv_layer(x) # 30 x 200 x 1024
        print(f"kv.size(): {kv.size()}")
        # Tạo query từ decoder output
        q = self.q_layer(y) # 30 x 200 x 512
        print(f"q.size(): {q.size()}")
        # Reshape và permute để tách thành các head
        kv = kv.reshape(batch_size, sequence_length, self.num_heads, 2 * self.head_dim)  # 30 x 200 x 8 x 128
        q = q.reshape(batch_size, sequence_length, self.num_heads, self.head_dim)  # 30 x 200 x 8 x 64
        kv = kv.permute(0, 2, 1, 3) # 30 x 8 x 200 x 128
        q = q.permute(0, 2, 1, 3) # 30 x 8 x 200 x 64
        # Chia kv thành key và value riêng
        k, v = kv.chunk(2, dim=-1) # K: 30 x 8 x 200 x 64, v: 30 x 8 x 200 x 64
        # Tính attention
        values, attention = scaled_dot_product(q, k, v, mask) #  30 x 8 x 200 x 64
        print(f"values: {values.size()}, attention:{attention.size()}")
        # Kết hợp các head lại
        values = values.reshape(batch_size, sequence_length, d_model) #  30 x 200 x 512
        # Qua lớp linear cuối cùng
        out = self.linear_layer(values)  #  30 x 200 x 512
        print(f"out after passing through linear layer: {out.size()}")
        return out  #  30 x 200 x 512


class DecoderLayer(nn.Module):
    # Một layer của decoder gồm 3 phần chính:
    # 1. Masked self-attention
    # 2. Encoder-decoder attention
    # 3. Position-wise feed forward
    def __init__(self, d_model, ffn_hidden, num_heads, drop_prob):
        super(DecoderLayer, self).__init__()
        # Masked self-attention
        self.self_attention = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.norm1 = LayerNormalization(parameters_shape=[d_model])
        self.dropout1 = nn.Dropout(p=drop_prob)
        # Encoder-decoder attention
        self.encoder_decoder_attention = MultiHeadCrossAttention(d_model=d_model, num_heads=num_heads)
        self.norm2 = LayerNormalization(parameters_shape=[d_model])
        self.dropout2 = nn.Dropout(p=drop_prob)
        # Feed forward
        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, drop_prob=drop_prob)
        self.norm3 = LayerNormalization(parameters_shape=[d_model])
        self.dropout3 = nn.Dropout(p=drop_prob)

    def forward(self, x, y, decoder_mask):
        # x: encoder output (30 x 200 x 512)
        # y: decoder input (30 x 200 x 512)
        # decoder_mask: mask để che các token tương lai (200 x 200)
        
        # Phần 1: Masked self-attention
        _y = y # Lưu input cho residual connection
        print("MASKED SELF ATTENTION")
        y = self.self_attention(y, mask=decoder_mask) # 30 x 200 x 512
        print("DROP OUT 1")
        y = self.dropout1(y) # 30 x 200 x 512
        print("ADD + LAYER NORMALIZATION 1")
        y = self.norm1(y + _y) # 30 x 200 x 512

        # Phần 2: Encoder-decoder attention
        _y = y # Lưu input cho residual connection
        print("CROSS ATTENTION")
        y = self.encoder_decoder_attention(x, y, mask=None) #30 x 200 x 512
        print("DROP OUT 2")  #30 x 200 x 512
        y = self.dropout2(y)
        print("ADD + LAYER NORMALIZATION 2")
        y = self.norm2(y + _y)  #30 x 200 x 512

        # Phần 3: Feed forward
        _y = y  #30 x 200 x 512
        print("FEED FORWARD 1")
        y = self.ffn(y) #30 x 200 x 512
        print("DROP OUT 3")
        y = self.dropout3(y) #30 x 200 x 512
        print("ADD + LAYER NORMALIZATION 3")
        y = self.norm3(y + _y) #30 x 200 x 512
        return y #30 x 200 x 512

class SequentialDecoder(nn.Sequential):
    # Lớp wrapper để chạy tuần tự các decoder layer
    def forward(self, *inputs):
        x, y, mask = inputs
        for module in self._modules.values():
            y = module(x, y, mask) #30 x 200 x 512
        return y

class Decoder(nn.Module):
    # Toàn bộ decoder stack gồm nhiều decoder layer
    def __init__(self, d_model, ffn_hidden, num_heads, drop_prob, num_layers=1):
        super().__init__()
        # Tạo stack các decoder layer
        self.layers = SequentialDecoder(*[DecoderLayer(d_model, ffn_hidden, num_heads, drop_prob) 
                                          for _ in range(num_layers)])

    def forward(self, x, y, mask):
        #x : encoder output (30 x 200 x 512) 
        #y : decoder input (30 x 200 x 512)
        #mask : mask để che các token tương lai (200 x 200)
        y = self.layers(x, y, mask)
        return y #30 x 200 x 512

# %%
d_model = 512
num_heads = 8
drop_prob = 0.1
batch_size = 30
max_sequence_length = 200
ffn_hidden = 2048
num_layers = 5

x = torch.randn( (batch_size, max_sequence_length, d_model) )  
y = torch.randn( (batch_size, max_sequence_length, d_model) ) 
mask = torch.full([max_sequence_length, max_sequence_length] , float('-inf'))
mask = torch.triu(mask, diagonal=1)
decoder = Decoder(d_model, ffn_hidden, num_heads, drop_prob, num_layers)
out = decoder(x, y, mask)
# Out:
# MASKED SELF ATTENTION
# x.size(): torch.Size([30, 200, 512])
# qkv.size(): torch.Size([30, 200, 1536])
# qkv after reshape .size(): torch.Size([30, 200, 8, 192])
# qkv after permutation: torch.Size([30, 8, 200, 192])
# q: torch.Size([30, 8, 200, 64]), k:torch.Size([30, 8, 200, 64]), v:torch.Size([30, 8, 200, 64])
# scaled.size() : torch.Size([30, 8, 200, 200])
# -- ADDING MASK of shape torch.Size([200, 200]) --
# values: torch.Size([30, 8, 200, 64]), attention:torch.Size([30, 8, 200, 200])
# values after reshaping: torch.Size([30, 200, 512])
# out after passing through linear layer: torch.Size([30, 200, 512])
# DROP OUT 1
# ADD + LAYER NORMALIZATION 1
# dims: [-1]
# Mean (torch.Size([30, 200, 1]))
# Standard Deviation  (torch.Size([30, 200, 1]))
# y: torch.Size([30, 200, 512])
# out: torch.Size([30, 200, 512])
# CROSS ATTENTION
# x.size(): torch.Size([30, 200, 512])
# kv.size(): torch.Size([30, 200, 1024])
# q.size(): torch.Size([30, 200, 512])
# ...

# %%
mask
# Out:
# tensor([[0., -inf, -inf,  ..., -inf, -inf, -inf],
#         [0., 0., -inf,  ..., -inf, -inf, -inf],
#         [0., 0., 0.,  ..., -inf, -inf, -inf],
#         ...,
#         [0., 0., 0.,  ..., 0., -inf, -inf],
#         [0., 0., 0.,  ..., 0., 0., -inf],
#         [0., 0., 0.,  ..., 0., 0., 0.]])
